# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
sns.set()

# %%
df=pd.read_csv('C:/Users/mostafa/AI&ML/CSV/ds_salaries.csv')

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# ...

# %%
df.sample(5)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 565         565       2022               SE              FT
# 200         200       2021               MI              FT
# 542         542       2022               MI              FT
# 501         501       2022               MI              FT
# 8             8       2020               MI              FT
#
#                  job_title  salary salary_currency  salary_in_usd  \
# 565          Data Engineer   54000             USD          54000
# 200         Data Scientist   52000             EUR          61467
# 542          Data Engineer  206699             USD         206699
# 501           Head of Data   30000             EUR          32974
# 8    Business Data Analyst  135000             USD         135000
#
#     employee_residence  remote_ratio company_location company_size
# 565                 US             0               US            M
# 200                 DE            50               AT            M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df['work_year'].unique()
# Out:
# array([2020, 2021, 2022], dtype=int64)

# %%
df['experience_level'].unique()
# Out:
# array(['MI', 'SE', 'EN', 'EX'], dtype=object)

# %%
df['employment_type'].unique()
# Out:
# array(['FT', 'CT', 'PT', 'FL'], dtype=object)

# %%
df['salary_currency'].unique() # Type of currency
# Out:
# array(['EUR', 'USD', 'GBP', 'HUF', 'INR', 'JPY', 'CNY', 'MXN', 'CAD',
#        'DKK', 'PLN', 'SGD', 'CLP', 'BRL', 'TRY', 'AUD', 'CHF'],
#       dtype=object)

# %%
df['salary_in_usd'].value_counts() # Salary by $
# Out:
# salary_in_usd
# 100000    15
# 120000    12
# 150000    12
# 200000    10
# 135000     9
#           ..
# 74000      1
# 61896      1
# 26005      1
# 22611      1
# 129000     1
# Name: count, Length: 369, dtype: int64

# %%
df['employee_residence'].unique() # Country
# Out:
# array(['DE', 'JP', 'GB', 'HN', 'US', 'HU', 'NZ', 'FR', 'IN', 'PK', 'PL',
#        'PT', 'CN', 'GR', 'AE', 'NL', 'MX', 'CA', 'AT', 'NG', 'PH', 'ES',
#        'DK', 'RU', 'IT', 'HR', 'BG', 'SG', 'BR', 'IQ', 'VN', 'BE', 'UA',
#        'MT', 'CL', 'RO', 'IR', 'CO', 'MD', 'KE', 'SI', 'HK', 'TR', 'RS',
#        'PR', 'LU', 'JE', 'CZ', 'AR', 'DZ', 'TN', 'MY', 'EE', 'AU', 'BO',
#        'IE', 'CH'], dtype=object)

# %%
df['remote_ratio'].unique() # 0=> insite , 50% insite and 50% remote ,100% full remote
# Out:
# array([  0,  50, 100], dtype=int64)

# %%
df['company_location'].unique()
# Out:
# array(['DE', 'JP', 'GB', 'HN', 'US', 'HU', 'NZ', 'FR', 'IN', 'PK', 'CN',
#        'GR', 'AE', 'NL', 'MX', 'CA', 'AT', 'NG', 'ES', 'PT', 'DK', 'IT',
#        'HR', 'LU', 'PL', 'SG', 'RO', 'IQ', 'BR', 'BE', 'UA', 'IL', 'RU',
#        'MT', 'CL', 'IR', 'CO', 'MD', 'KE', 'SI', 'CH', 'VN', 'AS', 'TR',
#        'CZ', 'DZ', 'EE', 'MY', 'AU', 'IE'], dtype=object)

# %%
df['company_size'].unique()
# Out:
# array(['L', 'S', 'M'], dtype=object)

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size]
# Index: []

# %%
df.duplicated().sum(
    
)
# Out:
# 0

# %% [markdown]
# # Preprocessing & Visualization

# %%
df.drop(labels='Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
df['job_title'].unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
# ...

# %%
df['job_title'] = df['job_title'].str.lower().str.strip()

# %%
df['job_title'].unique()
# Out:
# array(['data scientist', 'machine learning scientist',
#        'big data engineer', 'product data analyst',
#        'machine learning engineer', 'data analyst', 'lead data scientist',
#        'business data analyst', 'lead data engineer', 'lead data analyst',
#        'data engineer', 'data science consultant', 'bi data analyst',
#        'director of data science', 'research scientist',
#        'machine learning manager', 'data engineering manager',
#        'machine learning infrastructure engineer', 'ml engineer',
#        'ai scientist', 'computer vision engineer',
#        'principal data scientist', 'data science manager', 'head of data',
#        '3d computer vision researcher', 'data analytics engineer',
#        'applied data scientist', 'marketing data analyst',
#        'cloud data engineer', 'financial data analyst',
#        'computer vision software engineer',
#        'director of data engineering', 'data science engineer',
# ...

# %%
job_title_mapping = {
    "Data Scientist": [
        "data scientist", "lead data scientist", "staff data scientist", 
        "principal data scientist", "applied data scientist"
    ],
    "Machine Learning Scientist": [
        "machine learning scientist", "ai scientist", "ml engineer", 
        "applied machine learning scientist"
    ],
    "Big Data Engineer": [
        "big data engineer", "big data architect"
    ],
    "Product Data Analyst": [
        "product data analyst", "business data analyst", "marketing data analyst"
    ],
    "Machine Learning Engineer": [
        "machine learning engineer", "lead machine learning engineer", 
        "machine learning developer", "machine learning infrastructure engineer"
    ],
    "Data Analyst": [
        "data analyst", "bi data analyst", "financial data analyst", 
        "finance data analyst", "data analytics engineer", 
        "data analytics manager", "data analytics lead"
    ],
    "Data Engineer": [
        "data engineer", "cloud data engineer", "lead data engineer", 
        "principal data engineer", "data engineering manager", "etl developer"
    ],
    "Data Science Consultant": [
        "data science consultant"
    ],
    "Director of Data Science": [
        "director of data science", "head of data science"
    ],
    "Research Scientist": [
        "research scientist", "3d computer vision researcher"
    ],
    "Machine Learning Manager": [
        "machine learning manager", "head of machine learning"
    ],
    "Data Engineering Manager": [
        "data engineering manager", "director of data engineering"
    ],
    "AI Scientist": [
        "ai scientist", "nlp engineer", "computer vision engineer",
        "computer vision software engineer"
    ],
    "Data Science Manager": [
        "data science manager", "director of data science", 
        "head of data science"
    ],
    "Data Science Engineer": [
        "data science engineer"
    ],
    "Head of Data": [
        "head of data"
    ],
    "Data Analytics Engineer": [
        "data analytics engineer"
    ],
    "Lead Data Analyst": [
        "lead data analyst"
    ],
    "Principal Data Analyst": [
        "principal data analyst"
    ],
    "Data Specialist": [
        "data specialist"
    ],
    "Data Architect": [
        "data architect"
    ],
    "Finance Data Analyst": [
        "financial data analyst", "finance data analyst"
    ],
    "Principal Data Scientist": [
        "principal data scientist"
    ],
    "Applied Data Scientist": [
        "applied data scientist"
    ],
    "Director of Data Engineering": [
        "director of data engineering"
    ],
    "Staff Data Scientist": [
        "staff data scientist"
    ],
    "Analytics Engineer": [
        "analytics engineer"
    ]
}

# %%
reversed_mapping = {title: main_job for main_job, titles in job_title_mapping.items() for title in titles}

df['job_title_standardized'] = df['job_title'].map(reversed_mapping)

# %%
df['job_title_standardized'].unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Data Engineer',
#        'Lead Data Analyst', 'Data Science Consultant',
#        'Data Science Manager', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'AI Scientist', 'Principal Data Scientist', 'Head of Data',
#        'Data Analytics Engineer', 'Applied Data Scientist',
#        'Finance Data Analyst', 'Director of Data Engineering',
#        'Data Science Engineer', 'Data Specialist', 'Data Architect',
#        'Principal Data Analyst', 'Staff Data Scientist',
#        'Analytics Engineer'], dtype=object)

# %%
# df.drop('mapped_job_title',axis=1,inplace=True)

# %%
df['job_title_standardized'].unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Data Engineer',
#        'Lead Data Analyst', 'Data Science Consultant',
#        'Data Science Manager', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'AI Scientist', 'Principal Data Scientist', 'Head of Data',
#        'Data Analytics Engineer', 'Applied Data Scientist',
#        'Finance Data Analyst', 'Director of Data Engineering',
#        'Data Science Engineer', 'Data Specialist', 'Data Architect',
#        'Principal Data Analyst', 'Staff Data Scientist',
#        'Analytics Engineer'], dtype=object)

# %%
job_abbreviation = {
    'Data Scientist': 'DS',
    'Machine Learning Scientist': 'MLS',
    'Big Data Engineer': 'BDE',
    'Product Data Analyst': 'PDA',
    'Machine Learning Engineer': 'MLE',
    'Data Analyst': 'DA',
    'Data Engineer': 'DE',
    'Lead Data Analyst': 'LDA',
    'Data Science Consultant': 'DSC',
    'Data Science Manager': 'DSM',
    'Research Scientist': 'RS',
    'Machine Learning Manager': 'MLM',
    'Data Engineering Manager': 'DEM',
    'AI Scientist': 'AIS',
    'Principal Data Scientist': 'PDS',
    'Head of Data': 'HD',
    'Data Analytics Engineer': 'DAE',
    'Applied Data Scientist': 'ADS',
    'Finance Data Analyst': 'FDA',
    'Director of Data Engineering': 'DDE',
    'Data Science Engineer': 'DSE',
    'Data Specialist': 'DS',
    'Data Architect': 'DA',
    'Principal Data Analyst': 'PDA',  
    'Staff Data Scientist': 'SDS',
    'Analytics Engineer': 'AE'
}

# %%
df['job_title_standardized']=df['job_title_standardized'].map(job_abbreviation)

# %%
df['job_title_standardized'].unique()
# Out:
# array(['DS', 'MLS', 'BDE', 'PDA', 'MLE', 'DA', 'DE', 'LDA', 'DSC', 'DSM',
#        'RS', 'MLM', 'DEM', 'AIS', 'PDS', 'HD', 'DAE', 'ADS', 'FDA', 'DDE',
#        'DSE', 'SDS', 'AE'], dtype=object)

# %%
df.groupby(['work_year','employment_type']).sum(numeric_only=True)
# Out:
#                               salary  salary_in_usd  remote_ratio
# work_year employment_type
# 2020      CT                  100000         100000           100
#           FL                   60000          60000           100
#           FT                27338809        6700901          4300
#           PT                   33000          37635           150
# 2021      CT                  791000         791000           300
#           FL                   32000          32000            50
#           FT               117134233       20707160         14200
#           PT                  671760         138113           450
# 2022      CT                   29000          31875           100
#           FL                  100000         100000           100
#           FT                50228236       39311166         23100
#           PT                  150000         154957           100

# %%
pivot=pd.pivot_table(data=df,index=['employment_type'],columns="work_year",values=['salary','salary_in_usd','remote_ratio'],aggfunc='sum')
pivot
# Out:
#                 remote_ratio                  salary                       \
# work_year               2020   2021   2022      2020       2021      2022
# employment_type
# CT                       100    300    100    100000     791000     29000
# FL                       100     50    100     60000      32000    100000
# FT                      4300  14200  23100  27338809  117134233  50228236
# PT                       150    450    100     33000     671760    150000
#
#                 salary_in_usd
# work_year                2020      2021      2022
# employment_type
# CT                     100000    791000     31875
# FL                      60000     32000    100000
# FT                    6700901  20707160  39311166
# PT                      37635    138113    154957

# %%
plt.figure(figsize=(16,6))
sns.heatmap(pivot, annot=True, fmt="d", linewidths=.5)
# Out:
# <Axes: xlabel='None-work_year', ylabel='employment_type'>

# %%
pivot_2=pd.pivot_table(data=df,index=['experience_level'],columns="work_year",values=['salary','salary_in_usd'],aggfunc='mean').round(2)
pivot_2
# Out:
#                      salary                       salary_in_usd             \
# work_year              2020       2021       2022          2020       2021
# experience_level
# EN                338010.00  292888.85  131466.67      63648.60   59101.02
# EX                197500.00  216818.18  640298.08     202416.50  223752.73
# MI                539606.53  813117.78  131028.12      85950.06   85490.09
# SE                172733.33  424603.14  142481.88     137240.50  126596.19
#
#
# work_year              2022
# experience_level
# EN                 65423.43
# EX                178313.85
# MI                 91193.96
# SE                143043.40

# %%
plt.figure(figsize=(16,6))
sns.heatmap(pivot_2, annot=True, fmt=".2f", linewidths=.5)
# Out:
# <Axes: xlabel='None-work_year', ylabel='experience_level'>

# %%
pivot_3=pd.pivot_table(data=df,index=['employment_type'],columns="work_year",values=['salary','salary_in_usd'],aggfunc='mean').round(2)
pivot_3
# Out:
#                     salary                       salary_in_usd             \
# work_year             2020       2021       2022          2020       2021
# employment_type
# CT               100000.00  263666.67   29000.00     100000.00  263666.67
# FL                60000.00   16000.00  100000.00      60000.00   16000.00
# FT               402041.31  568612.78  159962.54      98542.66  100520.19
# PT                16500.00  111960.00   75000.00      18817.50   23018.83
#
#
# work_year            2022
# employment_type
# CT                31875.0
# FL               100000.0
# FT               125194.8
# PT                77478.5

# %%
plt.figure(figsize=(16,6))
sns.heatmap(pivot_3, annot=True, fmt=".2f", linewidths=.5)
# Out:
# <Axes: xlabel='None-work_year', ylabel='employment_type'>

# %%
sns.catplot(data=df,x='work_year',y='salary',kind='bar',hue='employment_type',aspect=2,height=6,palette='viridis')

# %%
sns.catplot(data=df,x='work_year',y='salary_in_usd',kind='bar',hue='employment_type',aspect=2,height=6,palette='viridis')
plt.ylabel('salary_in_usd $')
# Out:
# Text(45.56584110966435, 0.5, 'salary_in_usd $')

# %%
sns.displot(
    data=df,
    x="work_year", hue="remote_ratio",
    kind="kde",
    multiple="fill", clip=(0, None), height=6,
    palette="ch:rot=-.25,hue=1,light=.75",
    aspect=3,
)
plt.xticks(df['work_year'].unique())
# Out:
# ([<matplotlib.axis.XTick at 0x16569d41790>,
# ...
#  [Text(2020, 0, '2020'), Text(2021, 0, '2021'), Text(2022, 0, '2022')])

# %%
plt.figure(figsize=(16,6))
sns.lineplot(df,x='work_year',y='salary',hue='employment_type',palette="tab10", linewidth=2.5)
plt.xticks(df['work_year'].unique())
# Out:
# ([<matplotlib.axis.XTick at 0x165513a42c0>,
# ...
#  [Text(2020, 0, '2020'), Text(2021, 0, '2021'), Text(2022, 0, '2022')])

# %%
plt.figure(figsize=(14,6))
sns.boxplot(df,x='work_year',y='salary_in_usd',hue='company_size',palette='Blues')
# Out:
# <Axes: xlabel='work_year', ylabel='salary_in_usd'>

# %%
sns.catplot(data=df,x='employee_residence',y='salary',kind='bar',hue='work_year',aspect=3,height=5,palette='viridis',width=2)

# %%
sns.catplot(data=df,x='employee_residence',y='salary_in_usd',kind='bar',hue='work_year',aspect=3,height=5,palette='viridis',width=2)

# %%
plt.figure(figsize=(18,6))
sns.lineplot(data=df,x='employee_residence',y='remote_ratio')
plt.xticks(rotation=-45)
plt.tight_layout()

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=df,x='job_title_standardized',y='salary')
plt.tight_layout()

# %%
plt.figure(figsize=(16,6))
sns.boxplot(data=df,x='job_title_standardized',y='salary_in_usd',hue='employment_type')
plt.tight_layout()

# %%
plt.figure(figsize=(16,6))
sns.barplot(data=df,x='job_title_standardized',y='salary_in_usd',hue='experience_level',width=2)
plt.tight_layout()

# %%
plt.figure(figsize=(18,6))
sns.barplot(data=df,x='job_title_standardized',y='salary_in_usd',hue='company_size',width=1.5)
plt.tight_layout()

# %%
plt.figure(figsize=(18,6))
sns.lineplot(data=df,x='employee_residence',y='salary')
plt.xticks(rotation=-45)
plt.tight_layout()

# %%
plt.figure(figsize=(16,6))
sns.catplot(data=df,x='employment_type',y='salary' ,hue='experience_level' ,kind='bar',height=5,aspect=3,palette='viridis')
plt.tight_layout()

# %%
plt.figure(figsize=(16,6))
sns.catplot(data=df,x='employment_type',y='salary_in_usd' ,hue='experience_level' ,kind='bar',height=5,aspect=3,palette='mako')
plt.tight_layout()

# %%
sns.catplot(data=df,x='employment_type',y='remote_ratio',hue='company_size',kind='bar',height=6,aspect=3,palette='rocket_r')

# %%
plt.figure(figsize=(16,6))
sns.countplot(data=df,x='salary_currency',hue='employment_type',palette='rocket')
# Out:
# <Axes: xlabel='salary_currency', ylabel='count'>

# %%
plt.figure(figsize=(16,6))
plt.stem(df['company_location'],df['salary'])
plt.xlabel('company_location')
plt.ylabel('salary')
# Out:
# Text(0, 0.5, 'salary')

# %%
plt.figure(figsize=(16,6))
plt.stem(df['company_location'],df['salary_in_usd'])
plt.xlabel('company_location')
plt.ylabel('salary_in_usd $')
# Out:
# Text(0, 0.5, 'salary_in_usd $')

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=df,x='job_title_standardized',y='salary_in_usd',hue='company_size',palette='flare')
# Out:
# <Axes: xlabel='job_title_standardized', ylabel='salary_in_usd'>
